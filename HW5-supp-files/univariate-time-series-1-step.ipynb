# %%
import sys
import sklearn
import tensorflow as tf
from tensorflow import keras

import numpy as np
from numpy import load
import os

# to make this notebook's output stable across runs
np.random.seed(42)
tf.random.set_seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# Where to save the figures
PROJECT_ROOT_DIR = "."
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images")
os.makedirs(IMAGES_PATH, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %% [markdown]
# ## Load dataset

# %%
np.random.seed(42)

n_steps = 50
series = load('univariate-time-series-1-step.npy')

X_train, y_train = series[:7000, :n_steps], series[:7000, -1] # -1 references the last column
X_valid, y_valid = series[7000:9000, :n_steps], series[7000:9000, -1]
X_test, y_test = series[9000:, :n_steps], series[9000:, -1]

# %%
series.shape
# Out:
# (10000, 51, 1)

# %%
X_train.shape, y_train.shape
# Out:
# ((7000, 50, 1), (7000, 1))

# %%
def plot_series(series, y=None, y_pred=None, x_label="$t$", y_label="$x(t)$"):
    plt.plot(series, ".-")
    if y is not None:
        plt.plot(n_steps, y, "bx", markersize=10)
    if y_pred is not None:
        plt.plot(n_steps, y_pred, "ro")
    plt.grid(True)
    if x_label:
        plt.xlabel(x_label, fontsize=16)
    if y_label:
        plt.ylabel(y_label, fontsize=16, rotation=0)
    plt.hlines(0, 0, 100, linewidth=1)
    plt.axis([0, n_steps + 1, -1, 1])

fig, axes = plt.subplots(nrows=1, ncols=3, sharey=True, figsize=(12, 4))
for col in range(3):
    plt.sca(axes[col])
    plot_series(X_valid[col, :, 0], y_valid[col, 0],
                y_label=("$x(t)$" if col==0 else None))
save_fig("time_series_plot")
plt.show()
# Out:
# Saving figure time_series_plot

# %% [markdown]
# Linear predictions:

# %%
np.random.seed(42)
tf.random.set_seed(42)

#Replace this with your RNN code

model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[50, 1]),
    keras.layers.Dense(1)
])

model.compile(loss="mse", optimizer="adam")
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1147 - val_loss: 0.0487
# Epoch 2/20
# 219/219 [==============================] - 0s 674us/step - loss: 0.0387 - val_loss: 0.0253
# Epoch 3/20
# 219/219 [==============================] - 0s 720us/step - loss: 0.0241 - val_loss: 0.0184
# Epoch 4/20
# 219/219 [==============================] - 0s 692us/step - loss: 0.0190 - val_loss: 0.0154
# Epoch 5/20
# 219/219 [==============================] - 0s 679us/step - loss: 0.0161 - val_loss: 0.0132
# Epoch 6/20
# 219/219 [==============================] - 0s 665us/step - loss: 0.0139 - val_loss: 0.0117
# Epoch 7/20
# 219/219 [==============================] - 0s 669us/step - loss: 0.0120 - val_loss: 0.0101
# Epoch 8/20
# 219/219 [==============================] - 0s 697us/step - loss: 0.0104 - val_loss: 0.0090
# Epoch 9/20
# 219/219 [==============================] - 0s 683us/step - loss: 0.0091 - val_loss: 0.0079
# Epoch 10/20
# 219/219 [==============================] - 0s 669us/step - loss: 0.0081 - val_loss: 0.0072
# Epoch 11/20
# 219/219 [==============================] - 0s 692us/step - loss: 0.0072 - val_loss: 0.0064
# Epoch 12/20
# 219/219 [==============================] - 0s 697us/step - loss: 0.0065 - val_loss: 0.0060
# Epoch 13/20
# 219/219 [==============================] - 0s 692us/step - loss: 0.0060 - val_loss: 0.0055
# Epoch 14/20
# 219/219 [==============================] - 0s 633us/step - loss: 0.0056 - val_loss: 0.0053
# Epoch 15/20
# 219/219 [==============================] - 0s 642us/step - loss: 0.0052 - val_loss: 0.0050
# Epoch 16/20
# 219/219 [==============================] - 0s 688us/step - loss: 0.0050 - val_loss: 0.0048
# Epoch 17/20
# 219/219 [==============================] - 0s 697us/step - loss: 0.0047 - val_loss: 0.0048
# Epoch 18/20
# 219/219 [==============================] - 0s 701us/step - loss: 0.0046 - val_loss: 0.0046
# Epoch 19/20
# 219/219 [==============================] - 0s 706us/step - loss: 0.0044 - val_loss: 0.0044
# Epoch 20/20
# 219/219 [==============================] - 0s 724us/step - loss: 0.0043 - val_loss: 0.0043

# %%
model.evaluate(X_test, y_test)
# Out:
# 32/32 [==============================] - 0s 530us/step - loss: 0.0039
# 0.003911957610398531

# %%
def plot_learning_curves(loss, val_loss):
    plt.plot(np.arange(len(loss)) + 0.5, loss, "b.-", label="Training loss")
    plt.plot(np.arange(len(val_loss)) + 1, val_loss, "r.-", label="Validation loss")
    plt.gca().xaxis.set_major_locator(mpl.ticker.MaxNLocator(integer=True))
    plt.axis([1, 20, 0, 0.05])
    plt.legend(fontsize=14)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.grid(True)

plot_learning_curves(history.history["loss"], history.history["val_loss"])
plt.show()

# %%
y_pred = model.predict(X_test)
plot_series(X_test[15, :, 0], y_test[15, 0], y_pred[15, 0])
plt.show()

# %%
y_pred[15, 0]
# Out:
# 0.025370076

# %%
lstm_model = tf.keras.models.Sequential([

    tf.keras.layers.LSTM(128, return_sequences=True),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.LSTM(64, return_sequences=True),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.LSTM(32, return_sequences=True),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.LSTM(24),
    tf.keras.layers.Dropout(0.2),

#     tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=1)
])

# %%
lstm_model.compile(loss="mse", optimizer="adam")
history_lstm = lstm_model.fit(X_train, y_train, epochs=20,validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 17s 76ms/step - loss: 0.0929 - val_loss: 0.0538
# Epoch 2/20
# 219/219 [==============================] - 16s 72ms/step - loss: 0.0610 - val_loss: 0.0511
# Epoch 3/20
# 219/219 [==============================] - 16s 73ms/step - loss: 0.0512 - val_loss: 0.0302
# Epoch 4/20
# 219/219 [==============================] - 16s 73ms/step - loss: 0.0297 - val_loss: 0.0166
# Epoch 5/20
# 219/219 [==============================] - 16s 73ms/step - loss: 0.0184 - val_loss: 0.0089
# Epoch 6/20
# 219/219 [==============================] - 16s 73ms/step - loss: 0.0124 - val_loss: 0.0055
# Epoch 7/20
# 219/219 [==============================] - 16s 73ms/step - loss: 0.0101 - val_loss: 0.0048
# Epoch 8/20
# 219/219 [==============================] - 16s 73ms/step - loss: 0.0091 - val_loss: 0.0040
# Epoch 9/20
# 219/219 [==============================] - 16s 73ms/step - loss: 0.0086 - val_loss: 0.0043
# Epoch 10/20
# 219/219 [==============================] - 16s 74ms/step - loss: 0.0078 - val_loss: 0.0035
# Epoch 11/20
# 219/219 [==============================] - 16s 73ms/step - loss: 0.0074 - val_loss: 0.0030
# Epoch 12/20
# 219/219 [==============================] - 16s 75ms/step - loss: 0.0070 - val_loss: 0.0030
# Epoch 13/20
# 219/219 [==============================] - 16s 73ms/step - loss: 0.0070 - val_loss: 0.0033
# Epoch 14/20
# 219/219 [==============================] - 16s 73ms/step - loss: 0.0068 - val_loss: 0.0030
# Epoch 15/20
# 219/219 [==============================] - 16s 73ms/step - loss: 0.0065 - val_loss: 0.0036
# Epoch 16/20
# 219/219 [==============================] - 16s 73ms/step - loss: 0.0066 - val_loss: 0.0028
# Epoch 17/20
# 219/219 [==============================] - 16s 73ms/step - loss: 0.0065 - val_loss: 0.0029
# Epoch 18/20
# 219/219 [==============================] - 16s 74ms/step - loss: 0.0062 - val_loss: 0.0028
# Epoch 19/20
# 219/219 [==============================] - 16s 73ms/step - loss: 0.0062 - val_loss: 0.0030
# Epoch 20/20
# 219/219 [==============================] - 16s 73ms/step - loss: 0.0061 - val_loss: 0.0029

# %%
lstm_model.evaluate(X_test, y_test)
# Out:
# 32/32 [==============================] - 1s 19ms/step - loss: 0.0029
# 0.002933537121862173

# %%
def plot_learning_curves(loss, val_loss):
    plt.plot(np.arange(len(loss)) + 0.5, loss, "b.-", label="Training loss")
    plt.plot(np.arange(len(val_loss)) + 1, val_loss, "r.-", label="Validation loss")
    plt.gca().xaxis.set_major_locator(mpl.ticker.MaxNLocator(integer=True))
    plt.axis([1, 20, 0, 0.05])
    plt.legend(fontsize=14)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.grid(True)

plot_learning_curves(history_lstm.history["loss"], history.history["val_loss"])
plt.show()

# %%
y_pred_lstm = model.predict(X_test)
plot_series(X_test[15, :, 0], y_test[15, 0],y_pred_lstm[15, 0])
plt.show()

# %%
y_pred_lstm[15, 0]
# Out:
# 0.025370076
